# %%
#Importing Libraries

import pandas as pd
import matplotlib.pyplot as plt


# #Load data
df= pd.read_csv("data_jobs.csv")

#Data Cleanup

df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df['job_country'].value_counts().head(20)
# Out:
# job_country
# United States     206292
# India              51088
# United Kingdom     40375
# France             39922
# Germany            27694
# Spain              25100
# Singapore          23696
# Sudan              21781
# Netherlands        20631
# Italy              17013
# Canada             16029
# Mexico             15139
# Poland             14793
# Portugal           14508
# Australia          12955
# South Africa       12414
# Belgium            12078
# Philippines        11786
# Ireland            11162
# Switzerland         9924
# Name: count, dtype: int64

# %%
#find a country not listed
df['job_country'].isin(['North Korea']).any()
# Out:
# np.False_

# %%
uk_jobs = df[df['job_country']=='United Kingdom']

# %%
uk_jobs
# Out:
#               job_title_short  \
# 15              Data Engineer
# 45        Senior Data Analyst
# 74               Data Analyst
# 97               Data Analyst
# 152            Data Scientist
# ...                       ...
# 785485           Data Analyst
# 785513         Data Scientist
# 785522          Data Engineer
# 785642          Data Engineer
# 785676  Senior Data Scientist
#
#                                                 job_title    job_location  \
# 15                                          Data Engineer    Aberdeen, UK
# 45                                    Senior Data Analyst       Leeds, UK
# 74                       Data Entry/Economic Data Analyst   Worcester, UK
# 97      Systems & Data Analyst - Exploitation, Missing...  United Kingdom
# 152                                Data Science Team Lead        Anywhere
# ...                                                   ...             ...
# 785485                               Data Quality Analyst        Anywhere
# ...

# %%
uk_jobs =uk_jobs[uk_jobs['salary_year_avg'].notna()]

# %%
uk_jobs
# Out:
#               job_title_short                                       job_title  \
# 1107           Data Scientist         Data Scientist, Customer AI Engineering
# 2602             Data Analyst                            Admin & Data Analyst
# 9778      Senior Data Analyst  Workday HCM Senior Data Analyst (18 month FTC)
# 9903     Senior Data Engineer        Senior Satellite Analytics Data Engineer
# 13764          Data Scientist                    Programmatic Data Specialist
# ...                       ...                                             ...
# 781461         Data Scientist                                  Data Scientist
# 783284  Senior Data Scientist                           Senior Data Scientist
# 783436         Data Scientist                                 Insight Analyst
# 783598          Data Engineer                                   Data Engineer
# 783748          Data Engineer                                   Data Engineer
#
# ...

# %%
uk_jobs.groupby('job_title_short')['salary_year_avg'].agg(['median', 'min', 'max', 'count']).sort_values(by='median', ascending=False)
# Out:
#                              median      min       max  count
# job_title_short
# Senior Data Scientist      157500.0  72500.0  170575.0     31
# Machine Learning Engineer  149653.0  85205.0  200000.0      7
# Senior Data Engineer       147500.0  45000.0  171620.0     24
# Senior Data Analyst        111175.0  79200.0  118140.0      8
# Data Engineer              110000.0  35000.0  249000.0     60
# Data Scientist             105300.0  33488.5  205000.0     75
# Software Engineer           89100.0  89100.0  160000.0      5
# Data Analyst                87750.0  30000.0  180000.0     72
# Business Analyst            56700.0  30000.0   73500.0      5
